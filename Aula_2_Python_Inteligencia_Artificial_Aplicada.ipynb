# %% [markdown]
# <a href="https://colab.research.google.com/github/gvasquezcrs/python_ia_aplicada/blob/main/Aula_2_Python_Inteligencia_Artificial_Aplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 2**

# %%
import os
from google.colab import userdata
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
from google import genai

client = genai.Client()

# %%
respuesta = client.models.generate_content(model="gemini-2.5-flash", contents="Que es la IA")

# %%
print(respuesta.text)
# Out:
# La **Inteligencia Artificial (IA)** es un campo de la informática que se enfoca en crear máquinas y programas que pueden **razonar, aprender, comprender y actuar de manera inteligente**, similar a como lo haría un ser humano.
#
# En esencia, la IA busca dotar a las máquinas con la capacidad de realizar tareas que normalmente requieren inteligencia humana.
#
# **Características clave de la IA:**
#
# *   **Aprendizaje:** La capacidad de adquirir conocimientos y habilidades a partir de datos y experiencias, y mejorar su rendimiento con el tiempo. Esto se conoce como **aprendizaje automático (Machine Learning)**.
# *   **Razonamiento:** Utilizar la lógica y las reglas para sacar conclusiones y tomar decisiones.
# *   **Resolución de problemas:** Encontrar soluciones a situaciones complejas o desafíos.
# *   **Percepción:** Interpretar información sensorial, como imágenes (visión por computadora) o sonidos (procesamiento del lenguaje natural).
# *   **Comprensión del lenguaje natural (PLN):** Entender, interpretar y generar texto o voz humana.
# *   **Reconocimiento de patrones:** Identificar tendencias, anomalías y estructuras en grandes volúmenes de datos.
#
# **¿Cómo funciona?**
#
# La IA se basa en algoritmos complejos y, a menudo, en enormes cantidades de datos. Los sistemas de IA aprenden de estos datos para identificar patrones, hacer predicciones o tomar decisiones. Una rama muy importante es el **aprendizaje profundo (Deep Learning)**, que utiliza redes neuronales artificiales inspiradas en la estructura del cerebro humano para procesar información de manera aún más sofisticada.
#
# **Ejemplos cotidianos de IA:**
#
# *   **Asistentes virtuales:** Como Siri, Alexa o Google Assistant.
# *   **Sistemas de recomendación:** Lo que ves en Netflix, Spotify o Amazon.
# *   **Filtros de spam:** En tu correo electrónico.
# *   **Reconocimiento facial:** En tu smartphone o en cámaras de seguridad.
# *   **Coches autónomos:** Vehículos que pueden conducirse solos.
# *   **Diagnóstico médico:** Ayudando a identificar enfermedades a partir de imágenes o datos.
# *   **Traductores automáticos:** Como Google Translate.
# *   **Chatbots:** Atención al cliente automatizada.
#
# **Tipos de IA:**
#
# Generalmente se distinguen dos tipos principales:
#
# 1.  **IA Débil o Estrecha (ANI - Artificial Narrow Intelligence):** Es la IA que existe hoy en día. Está diseñada para realizar una tarea específica muy bien (ej. jugar ajedrez, reconocer caras, conducir un coche). No tiene conciencia ni inteligencia general para otras tareas.
# 2.  **IA Fuerte o General (AGI - Artificial General Intelligence):** Es una IA hipotética que tendría la capacidad intelectual de un ser humano en todas las áreas. Podría aprender cualquier tarea intelectual que un humano puede hacer. (Todavía no existe).
#
# En resumen, la IA busca emular la inteligencia humana en máquinas para que puedan realizar tareas complejas, aprender y adaptarse, abriendo un vasto abanico de posibilidades y transformando diversas industrias y aspectos de nuestra vida.

# %%
print("*********************")
# Out:
# *********************

# %%
n = 1

while n <=100:
  print("*")
  n=n+1
print("Ya salimos del while")

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
respuesta = chat.send_message("Que es la IA")

# %%
print(respuesta)

# %%
respuesta =chat.send_message("Cuando se lanzo chatGPT")
print(respuesta.text)
# Out:
# ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='Que es la IA'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""La **Inteligencia Artificial (IA)** es un campo de la informática que busca crear sistemas o máquinas que puedan realizar tareas que, normalmente, requerirían inteligencia humana.
#
#  En otras palabras, la IA es el esfuerzo por dotar a las máquinas de **capacidades cognitivas** que antes eran exclusivas de los seres humanos.
#
#  **Objetivo principal de la IA:**
#  Permitir que las máquinas **razonen, aprendan, tomen decisiones, comprendan el lenguaje, reconozcan patrones** y resuelvan problemas de manera autónoma, imitando o incluso superando ciertas capacidades cognitivas humanas.
#
#  **¿Cómo funciona (de manera simplificada)?**
#  La IA se basa en el desarrollo de **algoritmos y modelos matemáticos** que permiten a las máquinas procesar grandes cantidades de datos (Big Data), identificar patrones, aprender de la experiencia y hacer predicciones o tomar decisiones. En lugar de ser programadas explícitamente para cada posible escenario, los sistemas de IA son entrenados para aprender por sí mismos.
#
#  **Áreas clave y capacidades de la IA:**
#
#  1.  **Aprendizaje Automático (Machine Learning - ML):** Es una rama fundamental de la IA donde los sistemas aprenden de los datos sin ser programados explícitamente. Incluye técnicas como:
#      *   **Aprendizaje Supervisado:** Se entrena con datos etiquetados (ej. clasificar correos como spam o no spam).
#      *   **Aprendizaje No Supervisado:** Encuentra patrones en datos no etiquetados (ej. agrupar clientes por comportamiento).
#      *   **Aprendizaje por Refuerzo:** Un agente aprende a tomar decisiones interactuando con un entorno para maximizar una recompensa (ej. robots, juegos).
#  2.  **Redes Neuronales y Deep Learning:** Son un tipo de algoritmo de ML inspirado en la estructura y función del cerebro humano. El "Deep Learning" utiliza redes neuronales con muchas capas ("profundas") para aprender representaciones complejas de los datos, siendo crucial en campos como el reconocimiento de imágenes y el procesamiento del lenguaje.
#  3.  **Procesamiento del Lenguaje Natural (PLN/NLP):** Permite a las máquinas entender, interpretar y generar lenguaje humano. Es lo que hace posible los asistentes de voz, traductores automáticos y chatbots.
#  4.  **Visión por Computadora (Computer Vision):** Capacita a las máquinas para "ver" e interpretar imágenes y videos, identificando objetos, personas, lugares y acciones. Se usa en coches autónomos, reconocimiento facial y diagnóstico médico.
#  5.  **Robótica:** Integra la IA para permitir que los robots no solo realicen tareas físicas, sino que también interactúen con su entorno de manera inteligente, aprendiendo y adaptándose.
#  6.  **Sistemas Expertos:** Programas diseñados para emular la capacidad de toma de decisiones de un experto humano en un dominio específico.
#
#  **Tipos de IA:**
#
#  *   **IA Débil o Estrecha (Narrow AI / Weak AI):** Es la IA que existe hoy en día. Está diseñada y entrenada para una tarea específica (ej. jugar ajedrez, reconocer caras, responder preguntas en un asistente virtual). No tiene conciencia ni inteligencia general como un humano.
#  *   **IA Fuerte o General (General AI / Strong AI - AGI):** Es una IA hipotética que poseería la capacidad intelectual general de un ser humano, pudiendo realizar cualquier tarea intelectual que un humano puede hacer, aprender, comprender y aplicar el conocimiento en una amplia gama de situaciones. No existe actualmente.
#  *   **Superinteligencia Artificial (ASI):** Una IA hipotética que superaría drásticamente la inteligencia humana en casi todos los campos.
#
#  **Ejemplos cotidianos de IA:**
#
#  *   **Asistentes de voz:** Siri, Google Assistant, Alexa.
#  *   **Recomendaciones:** En Netflix, Amazon, Spotify.
#  *   **Filtros de spam:** En tu correo electrónico.
#  *   **Coches autónomos:** Aunque aún en desarrollo, usan IA para percibir y reaccionar al entorno.
#  *   **Reconocimiento facial:** En cámaras de seguridad o para desbloquear tu teléfono.
#  *   **Diagnóstico médico:** Asistiendo a los doctores en la detección de enfermedades.
#  *   **Generación de contenido:** Como ChatGPT (texto), DALL-E o Midjourney (imágenes), que pueden crear contenido nuevo a partir de indicaciones.
#
#  En resumen, la IA es el campo que busca enseñar a las máquinas a "pensar" y "aprender" para que puedan realizar tareas inteligentes, transformando casi todos los aspectos de nuestra sociedad."""
#      ),
#    ],
#    role='model'
#  ),
#  UserContent(
#    parts=[
#      Part(
#        text='Cuando se lanzo chatGPT'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.
#
#  Fue un lanzamiento que generó un enorme interés y un impacto significativo en el público general y en la industria tecnológica."""
#      ),
#    ],
#    role='model'
#  ),
#  UserContent(
#    parts=[
#      Part(
#        text='Cuando se lanzo chatGPT'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text='ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.'
#      ),
#    ],
#    role='model'
#  ),
#  UserContent(
#    parts=[
#      Part(
#        text='Cuando se lanzo chatGPT'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text='ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.'
#      ),
#    ],
#    role='model'
#  )]

# %%
prompt = input("Ingrese su pregunta: ")

while prompt != "fin":
  respuesta=chat.send_message(prompt)
  print(respuesta.text)
  prompt = input("Ingrese su pregunta (fin para terminar): ")
# Out:
# Ingrese su pregunta: es sana la lechuga responde si o no
# **Sí.**
# Ingrese su pregunta (fin para terminar): dime por que en 5 lineas
# Aquí tienes las razones en 5 líneas:
#
# 1.  Es **baja en calorías** y **alta en agua**, lo que favorece la hidratación y el control de peso.
# 2.  Es rica en **fibra**, esencial para una buena digestión y prevenir el estreñimiento.
# 3.  Aporta **vitaminas clave** como la A (para la visión), K (para huesos y coagulación) y folato.
# 4.  Contiene **minerales** como potasio y magnesio, importantes para el cuerpo.
# 5.  Sus **antioxidantes** protegen las células del daño, contribuyendo a la salud general.
# Ingrese su pregunta (fin para terminar): y si prefiero un chocolate
# ¡Ah, el chocolate! Entiendo perfectamente. Son dos alimentos con propósitos y perfiles nutricionales muy diferentes.
#
# 1.  **La lechuga** es un pilar para la salud diaria: aporta fibra, vitaminas, agua y muy pocas calorías, siendo fundamental para la digestión y la nutrición básica.
# 2.  **El chocolate**, especialmente el negro con alto porcentaje de cacao (70% o más), puede ofrecer antioxidantes y minerales, además de ser un gran placer para el paladar y un elevador de ánimo.
# 3.  La clave está en el **equilibrio y la moderación**. No son mutuamente excluyentes.
# 4.  Puedes disfrutar de la lechuga como parte de tus comidas principales para nutrir tu cuerpo.
# 5.  Y ocasionalmente, darte un gusto con un trozo de chocolate para el alma, pero sin que reemplace la base de una alimentación nutritiva.
# Ingrese su pregunta (fin para terminar): fin

# %%
nombres = ["Juan","Laura","Fernando","Josefina","Pedro"]
# pos.       0       1         2          3        4
print(nombres)
# Out:
# ['Juan', 'Laura', 'Fernando', 'Josefina', 'Pedro']

# %%
print("El quinto elemento es:",nombres[4])
# Out:
# El quinto elemento es: Pedro

# %%
promedios = [8.5,6.5,7.3,9.5,6.3,2.5,4.8]
print(promedios[3])
# Out:
# 9.5

# %%
n=0 #1

while n < len(promedios):
  promedios[n]=promedios[n]+1
  if promedios[n]>10:
     promedios[n]=10
  n=n+1
print("Los promedios mejorados son:",promedios)
# Out:
# Los promedios mejorados son: [9.5, 7.5, 8.3, 10, 6.3, 2.5, 4.8]

# %%
print("Cantidad de elementos en la lista:",len(promedios))
# Out:
# Cantidad de elementos en una lista: 7

# %%
promedios[-2]
# Out:
# 2.5

# %%
nombres=["Maria Silva","Fernanda Castro","Juan Perez","Rodrigo Feliz","Juana Lala"]
print(nombres)

nombres[:3]
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala']
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez']

# %%
nombres.append("Rogelio Rodriguez")
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala', 'Rogelio Rodriguez']

# %%
print("Cantidad de elementos:",len(nombres))
# Out:
# Cantidad de elementos: 6

# %%
nombres.extend(["Mateo Perez","Laura Fernan"])
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala', 'Rogelio Rodriguez', 'Mateo Perez', 'Laura Fernan']

# %%
nombres.append(["Juan Oroz","Pedro Pereyra"])

# %%
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala', 'Rogelio Rodriguez', 'Mateo Perez', 'Laura Fernan', ['Juan Oroz', 'Pedro Pereyra']]

# %%
nombres[8][1]
# Out:
# 'Pedro Pereyra'

# %%
nombres[-1][-1]
# Out:
# 'Pedro Pereyra'

# %%
nombres.remove("Maria Silva")

# %%
nombres
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Rodrigo Feliz',
#  'Juana Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez',
#  'Laura Fernan',
#  ['Juan Oroz', 'Pedro Pereyra']]

# %%
nombres.pop()
nombres
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Rodrigo Feliz',
#  'Juana Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez',
#  'Laura Fernan']

# %%
nombres.pop(2)
nombres
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Juana Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez',
#  'Laura Fernan']

# %% [markdown]
# Diccionarios:
#
# estudiantes=["clave":valor]

# %%
nombres=["Maria Silva","Fernanda Castro","Juan Perez","Rodrigo Feliz","Juana Lala"]
promedios = [8.5,6.5,7.3,9.5,6.3,2.5,4.8]

estudiantes = {
    "Maria Silva":8.5,
    "Fernanda Castro":6.5,
    "Juan Perez":7.3,
    "Rodrigo Feliz":6.3,
    "Juaan Lala":2.5
}

print(nombres)
print(promedios)
print(estudiantes)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala']
# [8.5, 6.5, 7.3, 9.5, 6.3, 2.5, 4.8]
# {'Maria Silva': 8.5, 'Fernanda Castro': 6.5, 'Juan Perez': 7.3, 'Rodrigo Feliz': 6.3, 'Juaan Lala': 2.5}

# %%
print(estudiantes["Maria Silva"])
print(estudiantes.get("Maria Silva"))
# Out:
# 8.5
# 8.5

# %%
print(estudiantes.items())
# Out:
# dict_items([('Maria Silva', 8.5), ('Fernanda Castro', 6.5), ('Juan Perez', 7.3), ('Rodrigo Feliz', 6.3), ('Juaan Lala', 2.5)])

# %%
estudiantes.pop("Maria Silva")
estudiantes
# Out:
# {'Fernanda Castro': 6.5,
#  'Juan Perez': 7.3,
#  'Rodrigo Feliz': 6.3,
#  'Juaan Lala': 2.5}

# %%
print(estudiantes.keys())
# Out:
# dict_keys(['Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juaan Lala'])

# %%
print(estudiantes.values())
# Out:
# dict_values([6.5, 7.3, 6.3, 2.5])

# %%
persona= {
    "nombre":"Juan Perez",
    "edad":25,
    "materias":["Matematica","Literatura","Dibujo"]
}

print(persona)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25, 'materias': ['Matematica', 'Literatura', 'Dibujo']}

# %%
estudiante1 = {
    "nombre":"Juan Perez","edad":25
    }

estudiante2 = {
    "nombre":"Laura Fernandez","edad":28
    }

print(estudiante1)
print(estudiante2)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}

# %%
lista_de_estudiantes= [
    {
    "nombre":"Juan Perez","edad":25
    },
    {
    "nombre":"Laura Fernandez","edad":28
    }
]

print(lista_de_estudiantes)
# Out:
# [{'nombre': 'Juan Perez', 'edad': 25}, {'nombre': 'Laura Fernandez', 'edad': 28}]

# %%
lista_de_estudiantes[1]
# Out:
# {'nombre': 'Laura Fernandez', 'edad': 28}

# %%
lista_de_estudiantes[1]["edad"]
# Out:
# 28
